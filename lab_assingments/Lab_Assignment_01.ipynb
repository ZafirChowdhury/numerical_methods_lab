# %% [markdown]
# <a href="https://colab.research.google.com/github/mirsazzathossain/CSE317-Lab/blob/main/Lab_Assignment_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Imports
import numpy as np

import matplotlib.pyplot as plt

import random

from PIL import Image

from IPython.display import display

# %% [markdown]
# #### **Homework 01:**
# Generate random matrix of size 10 x 5. Then, solve the following problems:

# %%
# Write your code to create the 10x5 random matrix here
matix = np.random.rand(10, 5)
print(matix)
# Out:
# [[0.30735306 0.21194698 0.94815172 0.35889588 0.13779732]
#  [0.17886981 0.34161647 0.08547965 0.96011189 0.66885486]
#  [0.1822105  0.68335291 0.37987811 0.13002848 0.81004657]
#  [0.91479113 0.23544159 0.5946608  0.34100658 0.13566953]
#  [0.90062132 0.70635011 0.96587547 0.36492766 0.38087   ]
#  [0.62895948 0.67070544 0.80972558 0.35751032 0.02840962]
#  [0.9091795  0.47008123 0.73913309 0.84158242 0.69675703]
#  [0.43882314 0.01401682 0.15878967 0.20355735 0.80368732]
#  [0.40146099 0.46765914 0.70333986 0.49797663 0.59201082]
#  [0.83337962 0.3023248  0.62531815 0.09123697 0.15553682]]

# %% [markdown]
# ##### **Problem 01:**
# Calculate the sum and mean of the 2nd row of the matrix.

# %%
# Write your code here
second_row =  matix[1]

print(f"Sum: {second_row.sum()}")
print(f"Mean: {second_row.mean()}")
# Out:
# Sum: 2.234932669183447
# Mean: 0.4469865338366894

# %% [markdown]
# ##### **Problem 02:**
# Find the sum and mean of all the rows of the matrix.

# %%
# Write your code here
sum = matix.sum()
mean = sum / (matix.shape[0] * matix.shape[1])

print(f"Sum: {sum}")
print(f"Mean: {mean}")
# Out:
# Sum: 24.365970229873298
# Mean: 0.487319404597466

# %% [markdown]
# ##### **Problem 03:**
# Find the mean of the 3rd column of the matrix without using the built-in function and loop.

# %%
# Write your code here
third_row = matix[2]
sum = third_row.sum()
mean = sum / len(third_row)

print(f"Mean: {mean}")
# Out:
# Mean: 0.43710331228199506

# %% [markdown]
# ##### **Problem 04:**
# Generate the vector `[25, 16, 9, 4, 1]` and then find the square root of each element of the vector using for loop. **Hint:** Use `np.sqrt()` function to find the square root of a number, don't use any other built-in function.

# %%
# Write your code here
vector = np.array([25, 16, 9, 4, 1])
sqrt_vector = []

for i in vector:
    sqrt_vector.append(np.sqrt(i))

print(f"Vector: {vector}")
print(f"Squre Vector: {sqrt_vector}")
# Out:
# Vector: [25 16  9  4  1]
# Squre Vector: [np.float64(5.0), np.float64(4.0), np.float64(3.0), np.float64(2.0), np.float64(1.0)]

# %% [markdown]
# ##### **Problem 05:**
# Write a function that takes a number and returns a vector like the previous problem. For example, if the input is 5, then the output should be `[25, 16, 9, 4, 1]`. If the input is 10, then the output should be `[100, 81, 64, 49, 36, 25, 16, 9, 4, 1]`.

# %%
# Write your code here
def generate_vector(n):
    vector = []
    for i in range(n):
        vector.append(random.randint(1, 100))

    return np.array(vector)

print(f"Vector: {generate_vector(10)}")
# Out:
# Vector: [56 45  5 75 22 10 50 36  7 77]

# %% [markdown]
# ##### **Problem 06:**
# Generate the following block matrix:
#
# $$
# \begin{bmatrix}
# 1 & 0 & 0 & 2 & 2 \\
# 0 & 1 & 0 & 2 & 2 \\
# 0 & 0 & 1 & 2 & 2 \\
# 25 & 16 & 9 & 4 & 1 \\
# \end{bmatrix}
# $$
#
# You can use any built-in function to generate the matrix.

# %%
# Write your code here
new_matix = np.matrix("1 0 0 2 2; 0 1 0 2 2; 0 0 1 2 2; 25 16 9 4 1")
print(f"Matix: {new_matix}")
# Out:
# Matix: [[ 1  0  0  2  2]
#  [ 0  1  0  2  2]
#  [ 0  0  1  2  2]
#  [25 16  9  4  1]]

# %% [markdown]
# ##### **Problem 07:**
# Plot $y = 2x^2 + 3x + 1$ for $x \in [-3, 3]$ with interval 0.25. You can use any built-in function to plot the graph.

# %%
# Write your code here
x = np.arange(-3, 3, 0.25)   # x∈[−3,3]
y = 2*(x**2) + 3*x + 1       # y=2x^2+3x+1

# Labels
plt.xlabel("X axis")
plt.ylabel("Y axis")

plt.title("y=2x^2+3x+1 for x∈[−3,3] at interval 0.25")

plt.legend(["y"])           # Not shwing proboblly because I only have 1 line

plt.plot(x, y)
plt.show()

# %% [markdown]
# ##### **Problem 08:**
# Plot $x + y + z = 1$ for $x, y \in [-3, 3]$ with interval 0.5. Use meshgrid to generate the grid. You can use any built-in function to plot the surface.

# %%
# Write your code here
x = np.arange(-3, 3, 0.5)       # x∈[−3,3]
y = np.arange(-3, 3, 0.5)       # y∈[−3,3]

x, y = np.meshgrid(x, y)        # generating meshgrid

z = 1 - x - y                   # x + y + z = 1 or z = 1 - x - y
                                # z = [1 - x1 - y1, 1 - x2 - y2, 1 - x3 - y3]

fig = plt.figure()              # Creating a new empty figure
fig = plt.axes(projection="3d") # Making the plot a 3d plot

fig.plot_surface(x, y, z)       # Ploting

plt.show()

# %% [markdown]
# ##### **Problem 09:**
# Download the image of Lena Forsen from the following link: [https://upload.wikimedia.org/wikipedia/en/7/7d/Lenna_%28test_image%29.png](https://upload.wikimedia.org/wikipedia/en/7/7d/Lenna_%28test_image%29.png). Then, do the following tasks:
#
# *  Load the image to a numpy array.
# *  Find the size of the image.
# *  Find the minimum and maximum value of the image.
# *  Find the mean and standard deviation of the image.
# *  Plot the image using `plt.imshow()` or `display()`.
# *  Resize the image to 50 x 50.
# *  Convert the image to grayscale.
# *  Plot the grayscale image using `plt.imshow()` or `display()`.
# *  Save the grayscale image using `imsave()`.
# *  Stack the columns of the image to form a vector of size 2500 x 1.

# %%
# Write your code here
# Loading the image
img = Image.open("/content/Lenna_(test_image).png")

# Load the image into np array
img_np_array = np.array(img)

# Size of the image
img_size = img.size
print(f"Image Size: {img_size}")

# Minimum and Maxium value of the image
min = img_np_array.min()
max = img_np_array.max()
print(f"Min: {min}")
print(f"Max: {max}")

# Mean and standard diviation
mean = img_np_array.mean()
std_div = np.std(img_np_array)
print(f"Mean: {mean}")
print(f"Standard Deviation: {std_div}")

# Plot the img
plt.imshow(img)

# Note to faculty -> I did the rest of problem 9 in the follwing code cell because I cant show 2 img plots in the same code cell
# Out:
# Image Size: (512, 512)
# Min: 3
# Max: 255
# Mean: 128.22837575276694
# Standard Deviation: 58.983724593480176

# %%
# Resize the image to 50x50
resized_img = img.resize((50, 50))
plt.imshow(resized_img)

# %%
# Conver the imgae to grayscale
gray_img = img.convert(mode="L") # L = 8bit pixels, so black and white
plt.imshow(gray_img)

# %%
# Save the gray scale image
gray_img.save("lena_test_img_grayscale.jpg")

# %%
# Stack the columns of the image to form a vector of size 2500 x 1.
# I am asuming I have to use the 50x50 resized image as other size cannot be converted into a 2500x1 vector

'''
from this
[[1, 2, 3],
[4, 5, 6]
[7, 8, 9]]

to this
[[1],
[4],
[7],
[2],
[5],
[8],
...]

Reshaping will stack the rows but I can transpose(interchaging rows with cols) the matix then use rshape to stack col
'''

resized_img_array = np.array(resized_img)

t_array = resized_img_array.T          # transpose the matix
stacked_col = t_array.reshape(-1, 1)   # shape becomes (2500, 1)
print(stacked_col)
# Out:
# [[226]
#  [226]
#  [227]
#  ...
#  [ 69]
#  [ 62]
#  [ 70]]

# %% [markdown]
# ##### **Problem 10:**
# Compute 2nd order Taylor approximation of $e^{2x}$ and $e^{3x}$, and $e^{5x}$ around $a = 0$ for $x \in [-1, 1]$ with interval 0.01. Then, determine which of the following is more accurate:
# > 1. Calculating the Taylor approximation separately for each $e^{2x}$, $e^{3x}$ then multiplying them together.
# > 2. Calculating the Taylor approximation for $e^{5x}$.
#
# Use mean square error (MSE) to determine the accuracy. Also, plot the Taylor approximation for 1st and 2nd method and the original function in the same plot for visual comparison.

# %%
# Write your code here

# Generalize the given fuctions
'''
e^2x, e^3x and e^5x can be generalized

f(x) = e^(kx)
f`(x) = ke^(kx)
f``(x) = k.e^(kx).k -> k^2.e^kx

at x = 0,
f(0) = 1
f`(0) = k
f``(0) = k^2

2nd order Taylor -> 1 + kx + (k^2.x^2)/2
k = nth term
'''
def taylor(k, x):
    return 1 + k*x + (k**2)*(x**2) / 2

x = np.arange(-1, 1, 0.01)

# Appox Value
taylor_e2x = taylor(x, 2)
taylor_e3x = taylor(x, 3)
taylor_e5x = taylor(x, 5)

# True Value
e2x = np.exp(x*2)
e3x = np.exp(x*3)
e5x = np.exp(x*5)

# Method 1
method_1_appox = taylor_e2x * taylor_e3x

# Method 2
method_2_appox = taylor_e5x

# MSE
mse_method_1 = np.mean((e5x - method_1_appox) ** 2)
mse_method_2 = np.mean((e5x - method_2_appox) ** 2)

print(f"Method 1: {mse_method_1}")
print(f"Method 2: {mse_method_2}")

print("Lower MSE is better")
print("Method 1 is better")

# Plot the results
plt.figure()
plt.plot(x, e5x, label="True e^5X")
plt.plot(x, method_1_appox, label="Method 1 Approximation")
plt.plot(x,method_2_appox, label="Method 2 Approxiation")
plt.legend()
plt.show()
# Out:
# Method 1: 424.7430505861696
# Method 2: 708.3015479335305
# Lower MSE is better
# Method 1 is better
